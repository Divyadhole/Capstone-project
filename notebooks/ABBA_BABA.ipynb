# %% [markdown]
# # ABBA–BABA Analysis Report
#
# ## Analysis Setup
# - **VCF File**: `PD_0603.variable.filtered.HF.snps.vcf.gz`
# - **Outgroup**: `PD_0588`
# - **Tree Structure**: `((PD_0598,PD_0603),PD_0602),PD_0588`
# - **Analysis Tool**: Dsuite v0.5
#
# ---
#
# ## Results Summary
#
# ### 1. ABBA–BABA Test (BBAA)
# **File:** `abba_baba_results_BBAA.txt`
#
# | P1      | P2      | P3      | D-statistic | Z-score     | p-value | f4-ratio | BBAA | ABBA | BABA |
# |---------|----------|---------|-------------|-------------|---------|----------|------|------|------|
# | PD_0602 | PD_0598  | PD_0603 | nan         | 3.01e-314   | nan     | nan      | 0    | 0    | 0    |
#
# ---
#
# ### 2. Tree-Based Test
# **File:** `abba_baba_results_tree.txt`
#
# | P1      | P2      | P3      | D-statistic | Z-score     | p-value | f4-ratio | BBAA | ABBA | BABA |
# |---------|----------|---------|-------------|-------------|---------|----------|------|------|------|
# | PD_0603 | PD_0598  | PD_0602 | nan         | 7.91e-323   | nan     | nan      | 0    | 0    | 0    |
#
# ---
#
# ### 3. Dmin Results
# **File:** `abba_baba_results_Dmin.txt`
#
# | P1 | P2 | P3 | D-statistic   | Z-score | p-value | f4-ratio | BBAA | ABBA | BABA |
# |----|----|----|----------------|---------|---------|----------|------|------|------|
# | —  | —  | —  | 2.50e-314      | —       | —       | —        | —    | —    | —    |
#
# ---
#
# ## Key Findings
#
# ### No Informative Sites Detected
# - **BBAA = 0**, **ABBA = 0**, **BABA = 0** in all tests
# - **D-statistic**: `nan` (not computable)
# - **p-value**: `nan` (cannot be calculated)
#
# ### Warning Messages
# 1. "Fewer than five blocks to calculate jackknife!!"
# 2. "Could not calculate p-values for the trio: PD_0598 PD_0602 PD_0603"
# 3. "It looks like there aren't enough ABBA-BABA informative variants for this trio"
#
# ---
#
# ## Possible Issues
#
# ### 1. Insufficient Variants
# - No ABBA or BABA patterns detected
# - Possible reasons:
#   - Overly strict VCF filtering
#   - Missing genotype data
#   - Incorrect sample names in VCF
#
# ### 2. Configuration Issues
# - Outgroup may be too closely related
# - Tree structure may be incorrect
#
# ### 3. VCF File Problems
# - File may be empty or corrupted
# - File may not contain expected samples
#
# ---
#
# ## Recommendations
#
# ### 1. Verify VCF Contents
# ```bash
# # Check VCF header for samples
# zcat PD_0603.variable.filtered.HF.snps.vcf.gz | grep '^#CHROM'
#
# # Count variants
# zcat PD_0603.variable.filtered.HF.snps.vcf.gz | grep -v '^#' | wc -l
